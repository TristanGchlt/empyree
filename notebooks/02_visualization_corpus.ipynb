# %%
import pandas as pd

# %%
from collections import Counter

# %%
corpus_path = "../data/processed/card_corpus.txt"
with open(corpus_path, "r", encoding="utf-8") as f:
    decks = [line.strip().split() for line in f]

print(f"Nombre de decks : {len(decks)}")
deck_lengths = [len(deck) for deck in decks]
print(f"Min/Max/Moy cartes par deck : {min(deck_lengths)}, {max(deck_lengths)}, {sum(deck_lengths)/len(deck_lengths):.2f}")
# Out:
# Nombre de decks : 20196
# Min/Max/Moy cartes par deck : 36, 97, 37.73

# %%
vocab = set(card for deck in decks for card in deck)
print(f"Taille du vocabulaire : {len(vocab)}")
# Out:
# Taille du vocabulaire : 1373

# %%
counter = Counter(card for deck in decks for card in deck)
print("Top 20 cartes les plus fréquentes :")
for card, freq in counter.most_common(20):
    print(card, freq)
# Out:
# Top 20 cartes les plus fréquentes :
# ALT_ALIZE_B_BR_34_C 11286
# ALT_CORE_B_BR_06_R1 11057
# ALT_CORE_B_OR_24_C 9616
# ALT_ALIZE_B_BR_32_C 8858
# ALT_CORE_B_YZ_21_C 8327
# ALT_CORE_B_OR_16_R1 7644
# ALT_CORE_B_OR_08_C 7432
# ALT_CORE_B_OR_05_R1 7346
# ALT_CORE_B_OR_14_C 7039
# ALT_CORE_B_BR_11_C 6701
# ALT_CORE_B_BR_15_C 6676
# ALT_CORE_B_YZ_04_C 6636
# ALT_CORE_B_LY_07_C 6474
# ALT_CORE_B_YZ_06_C 6474
# ALT_CORE_B_MU_13_C 6278
# ALT_CORE_B_BR_30_R1 6137
# ALT_CORE_B_MU_04_C 6023
# ALT_CORE_B_LY_23_C 5888
# ALT_ALIZE_B_MU_44_C 5861
# ALT_CORE_B_MU_16_R1 5791
