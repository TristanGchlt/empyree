# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec.load("../models/card2vec.model")

# %%
print(model.wv.most_similar("ALT_CORE_B_OR_01_C", topn=5))
# Out:
# [('ALT_CORE_B_OR_09_C', 0.7938931584358215), ('ALT_CORE_B_OR_05_R1', 0.7793958187103271), ('ALT_ALIZE_B_MU_31_R2', 0.775863766670227), ('ALT_CORE_B_YZ_20_R2', 0.7749345898628235), ('ALT_CORE_B_LY_15_R2', 0.7588077187538147)]
