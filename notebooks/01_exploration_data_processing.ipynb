# %% [markdown]
# ANALYSE EXPLORATOIRE DES DONNEES

# %%
import pandas as pd
from pathlib import Path

project_root = Path().resolve().parents[0]
data_path = project_root / "data" / "decoded" / "decoded_2025_12_04.csv"

# %%
decoded = pd.read_csv(data_path)
decoded.head()
# Out:
#                   updatedAt  \
# 0  2024-10-24T03:16:11.906Z
# 1  2024-10-24T03:16:11.948Z
# 2  2024-10-24T03:16:11.978Z
# 3  2024-10-24T03:16:12.007Z
# 4  2024-10-24T03:16:12.045Z
#
#                                             deckCode  \
# 0  ECAgXRACnal9g-yXSlpV02GpPqB1J6sdth3zW-dZhTv64d...
# 1  ECAgnRDtUBStS2wbZPpW0x6gdThE56sdhhWzW-9cW2HbLs...
# 2  ECAgmxjkIBS5TdqayDZMTi6zjZ8KaO2jbsISq3lkLuR86Z...
# 3  ECAgnRDsEBStS2wfSvpj1A6k9WNJwkhbfWuHX4mO-2LlzM...
# 4  ECAgXRACl6l9gsnxSVtKumw439QerK31rh157YuXOuw-m9...
#
#                                                cards
# 0  "1 ALT_CORE_B_OR_02_C\n2 ALT_COREKS_B_OR_09_R1...
# 1  "1 ALT_CORE_B_OR_02_C\n1 ALT_CORE_B_OR_21_R1\n...
# 2  "1 ALT_CORE_B_LY_03_C\n1 ALT_CORE_B_MU_16_R2\n...
# 3  "1 ALT_CORE_B_OR_02_C\n1 ALT_CORE_B_OR_16_R1\n...
# 4  "1 ALT_CORE_B_OR_02_C\n3 ALT_COREKS_B_OR_09_R1...

# %%
exemple = decoded["cards"][16010]

# %%
def split_cards(cards_string) :
    return cards_string[1:-1].split("\\n")

def remove_uniques(cards_list) :
    no_uniques = [elem for elem in cards_list if "_U_" not in elem]
    return no_uniques

def rename_ks_ids(cards_list) :
    no_ks = [elem.replace("COREKS", "CORE") for elem in cards_list]
    return no_ks

def alt_art_mapping(cards_list) :
    mapping = {
        # Sierra & Oddball
        "ALT_COREKS_B_AX_01_C" : "ALT_CORE_B_AX_01_C", 
        "ALT_CORE_P_AX_01_C" : "ALT_CORE_B_AX_01_C", 
        "ALT_ALIZE_B_AX_01_C" : "ALT_CORE_B_AX_01_C", 
        "ALT_WCS25_P_AX_01_C" : "ALT_CORE_B_AX_01_C", 
        "ALT_WCF25_P_AX_01_C" : "ALT_CORE_B_AX_01_C", 
        "ALT_DUSTERCB_P_AX_01_C" : "ALT_CORE_B_AX_01_C", 
        # Treyst & Rossum
        "ALT_COREKS_B_AX_02_C" : "ALT_CORE_B_AX_02_C", 
        "ALT_CORE_P_AX_02_C" : "ALT_CORE_B_AX_02_C", 
        "ALT_BISE_B_AX_02_C" : "ALT_CORE_B_AX_02_C", 
        "ALT_WCS25_P_AX_02_C" : "ALT_CORE_B_AX_02_C", 
        # Subhash & Marmo
        "ALT_COREKS_B_AX_03_C" : "ALT_CORE_B_AX_03_C", 
        "ALT_CORE_P_AX_03_C" : "ALT_CORE_B_AX_03_C", 
        "ALT_ALIZE_B_AX_03_C" : "ALT_CORE_B_AX_03_C", 
        "ALT_BISE_B_AX_03_C" : "ALT_CORE_B_AX_03_C", 
        "ALT_WCS25_P_AX_03_C" : "ALT_CORE_B_AX_03_C", 
        # Kojo & Boodah
        "ALT_COREKS_B_BR_01_C" : "ALT_CORE_B_BR_01_C", 
        "ALT_CORE_P_BR_01_C" : "ALT_CORE_B_BR_01_C", 
        "ALT_ALIZE_B_BR_01_C" : "ALT_CORE_B_BR_01_C", 
        "ALT_WCS25_P_BR_01_C" : "ALT_CORE_B_BR_01_C", 
        "ALT_WCF25_P_BR_01_C" : "ALT_CORE_B_BR_01_C", 
        "ALT_DUSTERCB_P_BR_01_C" : "ALT_CORE_B_BR_01_C", 
        # Basira & Kaizaimon
        "ALT_COREKS_B_BR_03_C" : "ALT_CORE_B_BR_03_C", 
        "ALT_CORE_P_BR_03_C" : "ALT_CORE_B_BR_03_C", 
        "ALT_ALIZE_B_BR_03_C" : "ALT_CORE_B_BR_03_C", 
        "ALT_BISE_B_BR_03_C" : "ALT_CORE_B_BR_03_C", 
        "ALT_WCS25_P_BR_03_C" : "ALT_CORE_B_BR_03_C", 
        # Atsadi & Surge
        "ALT_COREKS_B_BR_02_C" : "ALT_CORE_B_BR_02_C", 
        "ALT_CORE_P_BR_02_C" : "ALT_CORE_B_BR_02_C", 
        "ALT_BISE_B_BR_02_C" : "ALT_CORE_B_BR_02_C", 
        "ALT_WCS25_P_BR_02_C" : "ALT_CORE_B_BR_02_C", 
        # Nevenka & Blotch
        "ALT_COREKS_B_LY_01_C" : "ALT_CORE_B_LY_01_C", 
        "ALT_CORE_P_LY_01_C" : "ALT_CORE_B_LY_01_C",
        "ALT_BISE_B_LY_01_C" : "ALT_CORE_B_LY_01_C", 
        "ALT_WCS25_P_LY_01_C" : "ALT_CORE_B_LY_01_C", 
        "ALT_WCF25_P_LY_01_C" : "ALT_CORE_B_LY_01_C", 
        "ALT_DUSTERCB_P_LY_01_C" : "ALT_CORE_B_LY_01_C", 
        # Fen & Crowbar
        "ALT_COREKS_B_LY_03_C" : "ALT_CORE_B_LY_03_C", 
        "ALT_CORE_P_LY_03_C" : "ALT_CORE_B_LY_03_C", 
        "ALT_ALIZE_B_LY_03_C" : "ALT_CORE_B_LY_03_C", 
        "ALT_BISE_B_LY_03_C" : "ALT_CORE_B_LY_03_C", 
        "ALT_WCS25_P_LY_03_C" : "ALT_CORE_B_LY_03_C", 
        # Auraq & Kibble
        "ALT_COREKS_B_LY_02_C" : "ALT_CORE_B_LY_02_C", 
        "ALT_CORE_P_LY_02_C" : "ALT_CORE_B_LY_02_C", 
        "ALT_ALIZE_B_LY_02_C" : "ALT_CORE_B_LY_02_C", 
        "ALT_WCS25_P_LY_02_C" : "ALT_CORE_B_LY_02_C", 
        # Teija & Nauraa
        "ALT_COREKS_B_MU_01_C" : "ALT_CORE_B_MU_01_C", 
        "ALT_CORE_P_MU_01_C" : "ALT_CORE_B_MU_01_C", 
        "ALT_BISE_B_MU_01_C" : "ALT_CORE_B_MU_01_C", 
        "ALT_WCS25_P_MU_01_C" : "ALT_CORE_B_MU_01_C", 
        "ALT_WCF25_P_MU_01_C" : "ALT_CORE_B_MU_01_C", 
        "ALT_DUSTERCB_P_MU_01_C" : "ALT_CORE_B_MU_01_C", 
        # Rin & Orchid
        "ALT_COREKS_B_MU_03_C" : "ALT_CORE_B_MU_03_C", 
        "ALT_CORE_P_MU_03_C" : "ALT_CORE_B_MU_03_C", 
        "ALT_ALIZE_B_MU_03_C" : "ALT_CORE_B_MU_03_C",
        "ALT_BISE_B_MU_03_C" : "ALT_CORE_B_MU_03_C",
        "ALT_WCS25_P_MU_03_C" : "ALT_CORE_B_MU_03_C",
        # Arjun & Spike
        "ALT_COREKS_B_MU_02_C" : "ALT_CORE_B_MU_02_C",
        "ALT_CORE_P_MU_02_C" : "ALT_CORE_B_MU_02_C",
        "ALT_ALIZE_B_MU_02_C" : "ALT_CORE_B_MU_02_C",
        "ALT_WCS25_P_MU_02_C" : "ALT_CORE_B_MU_02_C",
        # Sigismar & Wingspan
        "ALT_COREKS_B_OR_01_C" : "ALT_CORE_B_OR_01_C",
        "ALT_CORE_P_OR_01_C" : "ALT_CORE_B_OR_01_C",
        "ALT_ALIZE_B_OR_01_C" : "ALT_CORE_B_OR_01_C",
        "ALT_WCS25_P_OR_01_C" : "ALT_CORE_B_OR_01_C",
        "ALT_WCF25_P_OR_01_C" : "ALT_CORE_B_OR_01_C",
        "ALT_DUSTERCB_P_OR_01_C" : "ALT_CORE_B_OR_01_C",
        # Gulrang & Tocsin
        "ALT_COREKS_B_OR_03_C" : "ALT_CORE_B_OR_03_C",
        "ALT_CORE_P_OR_03_C" : "ALT_CORE_B_OR_03_C",
        "ALT_ALIZE_B_OR_03_C" : "ALT_CORE_B_OR_03_C",
        "ALT_BISE_B_OR_03_C" : "ALT_CORE_B_OR_03_C",
        "ALT_WCS25_P_OR_03_C" : "ALT_CORE_B_OR_03_C",
        # Waru & Mack
        "ALT_COREKS_B_OR_02_C" : "ALT_CORE_B_OR_02_C",
        "ALT_CORE_P_OR_02_C" : "ALT_CORE_B_OR_02_C",
        "ALT_BISE_B_OR_02_C" : "ALT_CORE_B_OR_02_C",
        "ALT_WCS25_P_OR_02_C" : "ALT_CORE_B_OR_02_C",
        # Akesha & Taru
        "ALT_COREKS_B_YZ_01_C" : "ALT_CORE_B_YZ_01_C",
        "ALT_CORE_P_YZ_01_C" : "ALT_CORE_B_YZ_01_C",
        "ALT_ALIZE_B_YZ_01_C" : "ALT_CORE_B_YZ_01_C",
        "ALT_BISE_B_YZ_01_C" : "ALT_CORE_B_YZ_01_C",
        "ALT_WCS25_P_YZ_01_C" : "ALT_CORE_B_YZ_01_C",
        "ALT_WCF25_P_YZ_01_C" : "ALT_CORE_B_YZ_01_C",
        "ALT_DUSTERCB_P_YZ_01_C" : "ALT_CORE_B_YZ_01_C",
        # Afanas & Senka
        "ALT_COREKS_B_YZ_03_C" : "ALT_CORE_B_YZ_03_C",
        "ALT_CORE_P_YZ_03_C" : "ALT_CORE_B_YZ_03_C",
        "ALT_ALIZE_B_YZ_03_C" : "ALT_CORE_B_YZ_03_C",
        "ALT_BISE_B_YZ_03_C" : "ALT_CORE_B_YZ_03_C",
        "ALT_WCS25_P_YZ_03_C" : "ALT_CORE_B_YZ_03_C",
        # Lindiwe & Maw
        "ALT_COREKS_B_YZ_02_C" : "ALT_CORE_B_YZ_02_C",
        "ALT_CORE_P_YZ_02_C" : "ALT_CORE_B_YZ_02_C",
        "ALT_WCS25_P_YZ_02_C" : "ALT_CORE_B_YZ_02_C"
        # Entrainement Mécanique
        # Entrainement Physique
        # Entrainement A Capella
        # Entrainement a la Meditation
        # Entrainement a l'esprit d'equipe
        # Entrainement Magique
        # Pass : Col - Lac - Taiga - Toundra - Pic - Galerie
        # Promo Pack : Aroro - Sunisa - Sasika - Nyala - Gericht - Vaike
        # Pass : Fleche du Nilam - Grand Place - Ferme - Scene - Mess - Raffinerie
        # Promo Pack : Pasiphae - Ariane  - Minotaure - Dédale - Thesee - Icare
        # Promo Pack : Alelo - Saggita - Zaratan - Koi - Halua - Lucan
        # Tumult Champion : Entomologiste - Templier - Renarde - Bassisste - Duel de Cran - Grems
        # World Qualif : Meduse - Troupiere - Aloe - Encriere - Petit Djinn - Recup
        # Procu Judge
    }

def separation(cards_list) :
    decklist = []
    for elem in cards_list :
        if elem.startswith("3") :
            decklist.append(elem[2:])
            decklist.append(elem[2:])
            decklist.append(elem[2:])
        elif elem.startswith("2") :
            decklist.append(elem[2:])
            decklist.append(elem[2:])
        else :
            decklist.append(elem[2:])
    return decklist

# %%
exemple_split = split_cards(exemple)

# %%
exemple_split = remove_uniques(exemple_split)

# %%
exemple_split = rename_ks_ids(exemple_split)

# %%
exemple_split = separation(exemple_split)

# %%
exemple_split
# Out:
# ['ALT_CORE_B_OR_01_C',
#  'ALT_CORE_B_OR_05_R1',
#  'ALT_CORE_B_OR_05_R1',
#  'ALT_CORE_B_OR_14_C',
#  'ALT_CORE_B_OR_14_C',
#  'ALT_CORE_B_OR_16_R1',
#  'ALT_CORE_B_OR_16_R1',
#  'ALT_CORE_B_OR_16_R1',
#  'ALT_CORE_B_OR_05_R1',
#  'ALT_CORE_B_OR_06_C',
#  'ALT_CORE_B_OR_06_C',
#  'ALT_CORE_B_OR_06_C',
#  'ALT_CORE_B_OR_08_C',
#  'ALT_CORE_B_OR_08_C',
#  'ALT_CORE_B_OR_08_C',
#  'ALT_CORE_B_OR_09_C',
#  'ALT_CORE_B_OR_09_C',
#  'ALT_CORE_B_LY_15_R2',
#  'ALT_CORE_B_LY_15_R2',
#  'ALT_CORE_B_OR_24_C',
#  'ALT_CORE_B_OR_24_C',
#  'ALT_CORE_B_OR_24_C',
#  'ALT_CORE_B_YZ_20_R2',
#  'ALT_CORE_B_YZ_20_R2',
#  'ALT_BISE_B_MU_50_R2',
#  'ALT_BISE_B_MU_50_R2',
#  'ALT_BISE_B_OR_54_C',
#  'ALT_BISE_B_OR_54_C',
#  'ALT_BISE_B_OR_54_C',
#  'ALT_BISE_B_OR_59_C',
#  'ALT_BISE_B_OR_59_C',
#  'ALT_BISE_B_OR_59_C',
#  'ALT_ALIZE_B_MU_31_R2',
#  'ALT_ALIZE_B_MU_31_R2',
#  'ALT_ALIZE_B_MU_31_R2',
#  'ALT_ALIZE_B_OR_44_C',
#  'ALT_ALIZE_B_OR_44_C']
